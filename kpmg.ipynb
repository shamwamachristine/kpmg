# %%
import pandas as pd

# %%
df = pd.read_excel('/home/christine/Downloads/kpmg/KPMG_VI_New_raw_data_update_final.xlsx', sheet_name = None)

# %%
transactions = df['Transactions']

# %%
transactions.dropna(inplace = True)
transactions.info()
print('product_first_sold_date' in transactions.columns)
transactions
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 19445 entries, 0 to 19999
# Data columns (total 13 columns):
#  #   Column                   Non-Null Count  Dtype
# ---  ------                   --------------  -----
#  0   transaction_id           19445 non-null  int64
#  1   product_id               19445 non-null  int64
#  2   customer_id              19445 non-null  int64
#  3   transaction_date         19445 non-null  datetime64[ns]
#  4   online_order             19445 non-null  float64
#  5   order_status             19445 non-null  object
#  6   brand                    19445 non-null  object
#  7   product_line             19445 non-null  object
#  8   product_class            19445 non-null  object
#  9   product_size             19445 non-null  object
#  10  list_price               19445 non-null  float64
#  11  standard_cost            19445 non-null  float64
#  12  product_first_sold_date  19445 non-null  float64
# ...

# %%
transactions['year'] = transactions['transaction_date'].dt.year
transactions
# Out:
#        transaction_id  product_id  customer_id transaction_date  online_order  \
# 0                   1           2         2950       2017-02-25           0.0
# 1                   2           3         3120       2017-05-21           1.0
# 2                   3          37          402       2017-10-16           0.0
# 3                   4          88         3135       2017-08-31           0.0
# 4                   5          78          787       2017-10-01           1.0
# ...               ...         ...          ...              ...           ...
# 19995           19996          51         1018       2017-06-24           1.0
# 19996           19997          41          127       2017-11-09           1.0
# 19997           19998          87         2284       2017-04-14           1.0
# 19998           19999           6         2764       2017-07-03           0.0
# 19999           20000          11         1144       2017-09-22           1.0
#
# ...

# %%
transactions['profit']= transactions['list_price'] - transactions['standard_cost']
transactions
# Out:
#        transaction_id  product_id  customer_id transaction_date  online_order  \
# 0                   1           2         2950       2017-02-25           0.0
# 1                   2           3         3120       2017-05-21           1.0
# 2                   3          37          402       2017-10-16           0.0
# 3                   4          88         3135       2017-08-31           0.0
# 4                   5          78          787       2017-10-01           1.0
# ...               ...         ...          ...              ...           ...
# 19995           19996          51         1018       2017-06-24           1.0
# 19996           19997          41          127       2017-11-09           1.0
# 19997           19998          87         2284       2017-04-14           1.0
# 19998           19999           6         2764       2017-07-03           0.0
# 19999           20000          11         1144       2017-09-22           1.0
#
# ...

# %%
online = transactions['online_order'].value_counts()[1]
instore = transactions['online_order'].value_counts()[0]
print(online,instore)
print('there are', online, 'online sales and', instore, 'instore sales')
# Out:
# 9739 9706
# there are 9739 online sales and 9706 instore sales

# %%
transactions['brand'].value_counts()
# Out:
# Solex             4169
# WeareA2B          3245
# Giant Bicycles    3244
# OHM Cycles        2993
# Trek Bicycles     2931
# Norco Bicycles    2863
# Name: brand, dtype: int64

# %%
transactions.groupby('brand')['profit'].sum().sort_values(ascending = False)
# Out:
# brand
# WeareA2B          2.717686e+06
# Solex             2.355830e+06
# Trek Bicycles     1.807321e+06
# Giant Bicycles    1.541165e+06
# OHM Cycles        1.453562e+06
# Norco Bicycles    8.532516e+05
# Name: profit, dtype: float64

# %%
import seaborn as sns

# %%
sns.set_style('whitegrid')
plt.figure(figsize=(10,6))
sns.barplot(x=transactions.groupby('brand')['profit'].sum().sort_values(ascending=False).index,
            y=transactions.groupby('brand')['profit'].sum().sort_values(ascending=False).values)
plt.title('Profit per Brand')
plt.xlabel('Brand')
plt.ylabel('Profit')
plt.show()
# Profit per product line
transactions.groupby('product_line')['profit'].sum().sort_values(ascending=False)
# plot of profit per product line seaborn
sns.set_style('whitegrid')
plt.figure(figsize=(10,6))
sns.barplot(x=transactions.groupby('product_line')['profit'].sum().sort_values(ascending=False).index,
            y=transactions.groupby('product_line')['profit'].sum().sort_values(ascending=False).values)
plt.title('Profit per Product Line')
plt.xlabel('Product Line')
plt.ylabel('Profit')
plt.show()

# %%
customer_list = df['NewCustomerList']

# %%
customer_list
# Out:
#     first_name  last_name  gender  past_3_years_bike_related_purchases  \
# 0      Chickie    Brister    Male                                   86
# 1        Morly     Genery    Male                                   69
# 2      Ardelis  Forrester  Female                                   10
# 3       Lucine      Stutt  Female                                   64
# 4      Melinda     Hadlee  Female                                   34
# ..         ...        ...     ...                                  ...
# 995  Ferdinand  Romanetti    Male                                   60
# 996       Burk    Wortley    Male                                   22
# 997   Melloney      Temby  Female                                   17
# 998     Dickie    Cubbini    Male                                   30
# 999      Sylas    Duffill    Male                                   56
#
#            DOB                     job_title job_industry_category  \
# ...

# %%
customer_list.dropna(inplace = True)
customer_list
# Out:
#     first_name  last_name  gender  past_3_years_bike_related_purchases  \
# 0      Chickie    Brister    Male                                   86
# 1        Morly     Genery    Male                                   69
# 2      Ardelis  Forrester  Female                                   10
# 3       Lucine      Stutt  Female                                   64
# 4      Melinda     Hadlee  Female                                   34
# ..         ...        ...     ...                                  ...
# 995  Ferdinand  Romanetti    Male                                   60
# 996       Burk    Wortley    Male                                   22
# 997   Melloney      Temby  Female                                   17
# 998     Dickie    Cubbini    Male                                   30
# 999      Sylas    Duffill    Male                                   56
#
#            DOB                     job_title job_industry_category  \
# ...

# %% [markdown]
# ## How does the distribution of 'past_3_years_bike_related_purchases' vary across different 'wealth_segment' groups?

# %%
sns.boxplot(x='wealth_segment',y='past_3_years_bike_related_purchases',data=customer_list)
# Out:
# <AxesSubplot:xlabel='wealth_segment', ylabel='past_3_years_bike_related_purchases'>

# %% [markdown]
# # How does the distribution of 'past_3_years_bike_related_purchases' differ between customers who own a car and those who don't?

# %%
sns.histplot(x='past_3_years_bike_related_purchases', hue='owns_car', data=customer_list, multiple='stack')
# Out:
# <AxesSubplot:xlabel='past_3_years_bike_related_purchases', ylabel='Count'>

# %%
sns.boxplot(x='job_industry_category',y='past_3_years_bike_related_purchases',data=customer_list)
xticks = plt.xticks(rotation = 45)

# %%
customer_list.duplicated()
# Out:
# 0      False
# 1      False
# 2      False
# 3      False
# 4      False
#        ...
# 995    False
# 996    False
# 997    False
# 998    False
# 999    False
# Length: 715, dtype: bool

# %%
demographic = df['CustomerDemographic']

# %%
demographic.dropna(inplace = True)
demographic
# Out:
#       customer_id first_name  last_name  gender  \
# 0               1    Laraine  Medendorp       F
# 1               2        Eli    Bockman    Male
# 2               3      Arlin     Dearle    Male
# 8               9       Mala       Lind  Female
# 9              10   Fiorenze    Birdall  Female
# ...           ...        ...        ...     ...
# 3992         3993       Andi    Dumelow  Female
# 3993         3994    Stephie      Byars  Female
# 3994         3995      Rusty     Iapico    Male
# 3995         3996    Rosalia   Halgarth  Female
# 3996         3997     Blanch     Nisuis  Female
#
#       past_3_years_bike_related_purchases        DOB  \
# 0                                      93 1953-10-12
# 1                                      81 1980-12-16
# 2                                      61 1954-01-20
# 8                                      97 1973-03-10
# 9                                      49 1988-10-11
# ...                                   ...        ...
# ...

# %%
address = df['CustomerAddress']

# %%
address
# Out:
#       customer_id                    address  postcode            state  \
# 0               1         060 Morning Avenue      2016  New South Wales
# 1               2        6 Meadow Vale Court      2153  New South Wales
# 2               4         0 Holy Cross Court      4211              QLD
# 3               5        17979 Del Mar Point      2448  New South Wales
# 4               6           9 Oakridge Court      3216              VIC
# ...           ...                        ...       ...              ...
# 3994         3999            1482 Hauk Trail      3064              VIC
# 3995         4000  57042 Village Green Point      4511              QLD
# 3996         4001     87 Crescent Oaks Alley      2756              NSW
# 3997         4002           8194 Lien Street      4032              QLD
# 3998         4003            320 Acker Drive      2251              NSW
#
#         country  property_valuation
# 0     Australia                  10
# ...
